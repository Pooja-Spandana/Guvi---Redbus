# %%
# importing mysql.connector 

import pandas as pd
import mysql.connector

# %%
df = pd.read_csv(r'C:\Users\spand\Projects\REDBUS_APP\Redbus_data.csv')
df
# Out:
#                 State            Bus_name  \
# 0              Kerala         MMK Travels
# 1              Kerala       Kyros Connect
# 2              Kerala            SAAM BUS
# 3              Kerala          AdSAAM BUS
# 4              Kerala       NS Transports
# ...               ...                 ...
# 11693  Andhra Pradesh            True Bus
# 11694  Andhra Pradesh  DHANUNJAYA TRAVELS
# 11695  Andhra Pradesh  DHANUNJAYA TRAVELS
# 11696  Andhra Pradesh  Tranzindia Travels
# 11697  Andhra Pradesh       Amala Travels
#
#                                      Bus_type Departure Arrival  Duration  \
# 0                  A/C Seater / Sleeper (2+1)     22:30   07:30  09:00:00
# 1          Bharat Benz A/C Semi Sleeper (2+2)     23:00   09:00  10:00:00
# 2                        VE A/C Sleeper (2+1)     21:45   06:45  09:00:00
# 3                        VE A/C Sleeper (2+1)     20:10   06:45  10:35:00
# 4              Non A/C Seater / Sleeper (2+1)     21:45   06:10  08:25:00
# ...

# %%
# SQL connection

client = mysql.connector.connect(
    host = "localhost",
    user ="root",
    password ="root",
    database = "MD_114"
    )

print("Connection successful!")
cursor = client.cursor()
# Out:
# Connection successful!

# %%
# SQL query to create table

cursor.execute('''CREATE TABLE IF NOT EXISTS Red_bus(
                  ID INT AUTO_INCREMENT PRIMARY KEY,
                  State_name TEXT,
                  Bus_name TEXT,
                  Bus_type TEXT,
                  Departure TIME,
                  Arrival TIME,
                  Duration TEXT,
                  Price DECIMAL(10, 2),
                  Ratings FLOAT,
                  Seats_Available INT,
                  Route_link TEXT,
                  Route_name TEXT  
                  )''')

print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# SQL query to insert data into Red_bus table

insert_query = '''INSERT INTO Red_bus(
                  State_name,
                  Bus_name,
                  Bus_type,
                  Departure,
                  Arrival,
                  Duration,
                  Price,
                  Ratings,
                  Seats_Available,
                  Route_link,
                  Route_name  
                  )
                  VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

data = df.values.tolist()

cursor.executemany(insert_query, data)

client.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully

# %%
# SQL query to show data in table

query = "select * from Red_bus"
cursor.execute(query)

for data in cursor:
    print(data)
# Out:
# (1, 'Kerala', 'MMK Travels', 'A/C Seater / Sleeper (2+1)', datetime.timedelta(seconds=81000), datetime.timedelta(seconds=27000), '09:00:00', Decimal('1299.00'), 4.3, 15, 'https://www.redbus.in/bus-tickets/bangalore-to-kozhikode', 'Bangalore to Kozhikode')
# (2, 'Kerala', 'Kyros Connect', 'Bharat Benz A/C Semi Sleeper (2+2)', datetime.timedelta(seconds=82800), datetime.timedelta(seconds=32400), '10:00:00', Decimal('1699.00'), 4.3, 20, 'https://www.redbus.in/bus-tickets/bangalore-to-kozhikode', 'Bangalore to Kozhikode')
# (3, 'Kerala', 'SAAM BUS', 'VE A/C Sleeper (2+1)', datetime.timedelta(seconds=78300), datetime.timedelta(seconds=24300), '09:00:00', Decimal('1800.00'), 4.4, 11, 'https://www.redbus.in/bus-tickets/bangalore-to-kozhikode', 'Bangalore to Kozhikode')
# ...
